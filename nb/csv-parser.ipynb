# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import config

import comborun
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv(config.DATA_DIR/"bg_red_log.csv")
df = df[2756:]
df = df.dropna(how='all')

#df.drop(['Experimentator', 'Binning'], axis=1)
del_cols = ['Binning', 'Comment', 'Rga', 'Data', 'Delay, ns', 'Flow.6','Flat Field ', 
            'Conc.', 'Size','Magn.', 'Experimentator', 'background', 'Flow.3',
           'upper Nozzle', 'lower Nozzle', 'capillary ID', 'Scatt.', 'Zoom', 'focusing lens', 'Injector distance']
df = df.drop(del_cols, axis=1)
#df = df.dropna(subset=['data analysis'])

# %%
df20nm = df[df['Description'].str.startswith('20nm PS', na=False)]#[-20:]
df30nm = df[df['Description'].str.startswith('30nm PS', na=False)]#[-20:]
df40nm = df[df['Description'].str.startswith('40nm PS', na=False)]#[-20:]


print(df20nm.shape, df30nm.shape, df40nm.shape)
# Out:
# (20, 24) (52, 24) (88, 24)

# %%
df20nm
# Out:
#                  Description                      Experiment name  \
# 3081  20nm PS E13 in 20 AmAc  injector 2 and He at injector 10 ml
# 3082  20nm PS E13 in 20 AmAc  injector 2 and He at injector 10 ml
# 3085  20nm PS E13 in 20 AmAc  injector 2 and He at injector 15 ml
# 3086  20nm PS E13 in 20 AmAc  injector 2 and He at injector 15 ml
# 3087  20nm PS E13 in 20 AmAc  injector 2 and He at injector 15 ml
# 3088  20nm PS E13 in 20 AmAc  injector 2 and He at injector 15 ml
# 3089  20nm PS E13 in 20 AmAc  injector 2 and He at injector 15 ml
# 3090  20nm PS E13 in 20 AmAc  injector 2 and He at injector 15 ml
# 3093  20nm PS E13 in 20 AmAc  injector 2 and He at injector 20 ml
# 3094  20nm PS E13 in 20 AmAc  injector 2 and He at injector 20 ml
# 3095  20nm PS E13 in 20 AmAc  injector 2 and He at injector 20 ml
# 3096  20nm PS E13 in 20 AmAc  injector 2 and He at injector 20 ml
# 3097  20nm PS E13 in 20 AmAc  injector 2 and He at injector 20 ml
# ...

# %%
#for col in df.columns.tolist():
#    print(f'_{col}_')
#    print(f'\t{df[col].unique().shape}')
#    if df[col].unique().shape[0] < 10:
#        print(df[col].unique())
#    print()

# %%
#### 20nm 969-978
#### 30nm 1015-1024
#### 30nm 796-801
#### 40nm 894-903

# %%
file_paths = list(map(lambda x: f'/home/tejvarmay/scattering_data/data/newdata/{x[:-4]}_analysis_d20/spts.cxi', df20nm['File']))
c = comborun.ComboRun(file_paths[:5])
#c.filter_y(90, 280)
#c.filter_x(75, 175)
#c.filter_i(5)
c.scatter_xi()
c.hist_i()
plt.axvline(x=np.median(c.peak_is**(1/6)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[112], line 2
#       1 file_paths = list(map(lambda x: f'/home/tejvarmay/scattering_data/data/newdata/{x[:-4]}_analysis_d20/spts.cxi', df20nm['File']))
# ----> 2 c = comborun.ComboRun(file_paths[:5])
#       3 #c.filter_y(90, 280)
#       4 #c.filter_x(75, 175)
#       5 #c.filter_i(5)
#
# File ~/spts-ana/src/comborun/__init__.py:28, in ComboRun.__init__(self, fnames, hit_type)
#      22 self.img_inds = np.array([], dtype=int)
#      25 for i, fname in enumerate(self.fnames):
# ---> 28     with h5py.File(fname, 'r')  as f:
#      29
#      30         #number of peaks in each frame. almost all 0s, size about 2000
#      31         run_npeaks = f['5_detect/n'][:]
#      32         run_hits_loc =  np.where(run_npeaks>0)[0] #both single and multi
#
# ...

# %%
c = comborun.ComboRun(file_paths[14])
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 c = comborun.ComboRun(file_paths[14])
#
# File ~/spts-ana/src/comborun/__init__.py:28, in ComboRun.__init__(self, fnames, hit_type)
#      22 self.img_inds = np.array([], dtype=int)
#      25 for i, fname in enumerate(self.fnames):
# ---> 28     with h5py.File(fname, 'r')  as f:
#      29
#      30         #number of peaks in each frame. almost all 0s, size about 2000
#      31         run_npeaks = f['5_detect/n'][:]
#      32         run_hits_loc =  np.where(run_npeaks>0)[0] #both single and multi
#
# ...
