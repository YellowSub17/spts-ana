# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import comborun
from config import generate_full_paths, ps_data_ranges
import h5py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
group = 'ps20nm'
cbr1 = comborun.ComboRun(generate_full_paths(ps_data_ranges[group], 25))
#cbr2 = comborun.ComboRun(generate_full_paths(ps_data_ranges[group], 7))

#cbr1.filter_focused(cbr2)
#cbr1.scatter_xy()

# %%
cbr1.peak_area
# Out:
# array([ 48.,  31., 183., ...,  41.,  49.,  28.], shape=(1818,))

# %%
cbr1.peak_circum
# Out:
# array([27., 20., 60., ..., 27., 28., 20.], shape=(1818,))

# %%
all_thbn = []
all_filters =[]
all_tags = []
for group in ps_data_ranges.keys():
    
    cbr = comborun.ComboRun(generate_full_paths(ps_data_ranges[group], 25))
    print(f'{group}: with {cbr.peak_xs.size} peaks.')
    cbr_thbn = cbr.get_thumbnails()
    all_thbn.append(cbr_thbn)



result = np.concatenate(all_thbn, axis=0)
#np.save(f'{config.DATA_DIR}/thumbnails.npy',result)
# Out:
# ps20nm: with 1818 peaks.
# Generating thumbnails...
# 385	/1818
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       6     cbr = comborun.ComboRun(generate_full_paths(ps_data_ranges[group], 25))
#       7     print(f'{group}: with {cbr.peak_xs.size} peaks.')
# ----> 8     cbr_thbn = cbr.get_thumbnails()
#       9     all_thbn.append(cbr_thbn)
#      13 result = np.concatenate(all_thbn, axis=0)
#
# File ~/spts-ana/src/comborun/comborun.py:123, in ComboRun.get_thumbnails(self, r, n_thumbs)
#     120 fname = self.fnames[self.fname_inds[i_peak]]
#     121 file_i = self.img_inds[i_peak]
# --> 123 with h5py.File(fname, 'r')  as file:
#     124     thumbnail = file['/2_process/image'][file_i, peak_y_int-r: peak_y_int+r, peak_x_int-r:peak_x_int+r]
#     125     thumbnails[i_peak] = thumbnail.astype(np.float32)
#
# File ~/miniconda3/envs/spts-stable/lib/python3.10/site-packages/h5py/_hl/files.py:555, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, track_times, **kwds)
#     546     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     547                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     548                      alignment_threshold=alignment_threshold,
#     549                      alignment_interval=alignment_interval,
#     550                      meta_block_size=meta_block_size,
#     551                      **kwds)
#     552     fcpl = make_fcpl(track_order=track_order, track_times=track_times,
#     553                      fs_strategy=fs_strategy, fs_persist=fs_persist,
#     554                      fs_threshold=fs_threshold, fs_page_size=fs_page_size)
# --> 555     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     557 if isinstance(libver, tuple):
#     558     self._libver = libver
#
# File ~/miniconda3/envs/spts-stable/lib/python3.10/site-packages/h5py/_hl/files.py:232, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     230     if swmr:
#     231         flags |= h5f.ACC_SWMR_READ
# --> 232     fid = h5f.open(name, flags, fapl=fapl)
#     233 elif mode == 'r+':
#     234     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:106, in h5py.h5f.open()
#
# File h5py/_objects.pyx:196, in h5py._objects.ObjectID.__cinit__()
#
# File h5py/_objects.pyx:201, in h5py._objects.ObjectID.__cinit__()
#
# File ~/miniconda3/envs/spts-stable/lib/python3.10/weakref.py:165, in WeakValueDictionary.__setitem__(self, key, value)
#     162 def __repr__(self):
#     163     return "<%s at %#x>" % (self.__class__.__name__, id(self))
# --> 165 def __setitem__(self, key, value):
#     166     if self._pending_removals:
#     167         self._commit_removals()
#
# KeyboardInterrupt:
